# %% [markdown]
# # **<font color='red'>NN BASELINE</font>**
# **<font color='blue'>In this notebook i have implemented a baseline model of Neural Network (do let me know if you have any doubts or find any bugs)</font>**
#
#
# * **SCOPE OF IMPROVEMENTS**
# 1. **i haven't tested effect of batch size**
# 2. **adding layers**
# 3. **feature engineering on combined train and test data.**
# 4. **analize train and test distribution carefully.**
# 5. **try different optimizers (Nadam,AdamW,Adagrad etc.)**
# 6. **try different scheduling techniques.**

# %% [markdown]
# # **<font color='green'>IMPORT LIBRARIES</font>**

# %%
from IPython.core.display import display, HTML

import pandas as pd
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import glob
import os
import gc

from joblib import Parallel, delayed

from sklearn import preprocessing, model_selection
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import QuantileTransformer
from sklearn.metrics import r2_score

import matplotlib.pyplot as plt 
import seaborn as sns
import numpy.matlib


path_submissions = '/'

target_name = 'target'
scores_folds = {}

sns.set_style("darkgrid")

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

import warnings
warnings.filterwarnings("ignore") 
        
pd.options.display.max_columns = 1000
pd.options.display.max_rows = 1000


# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
train=pd.read_csv("train.csv")
test=pd.read_csv("test.csv")

# %%
print("train shape is:",train.shape)
print("test shape is:",test.shape)
# Out:
# train shape is: (600000, 102)
# test shape is: (540000, 101)

# %%
train.head()
# Out:
#    id        f0       f1        f2       f3        f4       f5       f6  \
# 0   0  0.106643  3.59437  132.8040  3.18428  0.081971  1.18859  3.73238
# 1   1  0.125021  1.67336   76.5336  3.37825  0.099400  5.09366  1.27562
# 2   2  0.036330  1.49747  233.5460  2.19435  0.026914  3.12694  5.05687
# 3   3 -0.014077  0.24600  779.9670  1.89064  0.006948  1.53112  2.69800
# 4   4 -0.003259  3.71542  156.1280  2.14772  0.018284  2.09859  4.15492
#
#          f7       f8        f9       f10       f11       f12       f13  \
# 0  2.266270  2.09959  0.012330  1.607190 -0.318058  0.560137  2.806880
# 1 -0.471318  4.54594  0.037706  0.331749  0.325091  0.062040  2.262150
# 2  3.849460  1.80187  0.056995  0.328684  2.968810  0.105244  2.069490
# 3  4.517330  4.50332  0.123494  1.002680  4.869600  0.058411  2.497850
# 4 -0.038236  3.37145  0.034166  0.711483  0.769988  0.057555  0.957257
#
#        f14       f15       f16       f17      f18       f19       f20  \
# 0  1.35114  2.535930  0.197527  0.676494  1.98979 -3.842450  0.037380
# 1  4.33943 -0.224999  0.233586  3.381280  1.90299  0.067874 -0.051268
# 2  5.30986  1.354790 -0.262018  1.379080  1.48091  0.020542 -0.008806
# 3  1.23843  2.348360  0.175475  1.608890  2.02881  0.042086  0.005141
# 4  3.71145  5.464350  0.287104  2.616950  1.38403  0.074883 -0.010543
#
#         f21      f22       f23       f24      f25      f26       f27  \
# 0  0.230322  3.33055  0.009397  0.144738  3.05131  1.30362  0.033225
# 1  0.006135  2.60444  0.103441  0.067638  4.75362  1.85552 -0.181834
# 2  0.109348  1.68365  0.038180  0.123716  1.11248  3.57166  0.120601
# 3  0.076506  1.65122  0.111813  0.121641  0.58912  4.23692 -0.032843
# 4  0.109121  2.27602  0.008023  0.045235  4.35954  5.07562 -0.009376
#
#         f28       f29       f30       f31       f32       f33       f34  \
# 0 -0.018284  2.748210 -0.009294 -0.036271 -0.049871  0.019484  3.898460
# 1  0.008359  3.166340  0.011850  0.022292  0.069320  0.117109  0.315276
# 2  0.082069  2.233520  0.002270  0.045182  0.014405  0.011599 -0.502849
# 3  0.058168  0.712927  0.097465  0.072744  0.000324  0.063362  4.063820
# 4  0.528966  4.053350  0.020000  0.106828  0.051307  0.045939  3.402460
#
#        f35       f36       f37      f38       f39      f40       f41  \
# 0  11.2863  1.138020  3.366880  4.94446 -0.105772  2.11345  3.452230
# 1  24.4807  1.672270 -0.409067  4.95475  0.092358  2.60318  1.954690
# 2  33.7382  1.417500  1.071350  3.22296  2.122030  3.08216  0.637555
# 3  25.3824  0.576572  2.026210  2.96843  1.085670  1.71088  1.371820
# 4  15.5615  1.635960  0.047029  4.01771  0.155748  5.28998  4.118920
#
#         f42       f43       f44       f45       f46      f47       f48  \
# 0  0.789430  1.113210   1.49157  2.440370  0.041824  3.35537  0.053691
# 1  0.005896  3.289340   2.56453  0.817706  0.025997  4.61749  1.575540
# 2 -0.006822 -0.390943  17.34570  3.700430 -0.033600  1.57824  0.051978
# 3  0.034631  0.722607  71.44850  3.034580  0.092245  3.45310  0.044829
# 4  0.072155  2.752150   3.17116  0.693346 -0.105861  3.32055  0.090698
#
#         f49       f50       f51       f52       f53       f54       f55  \
# 0  1.701270  0.908831  0.094902  0.030219  0.597024  4.443410  1.586490
# 1  0.066105  0.681634  0.025247  0.183500  0.110038  2.746120  0.835586
# 2 -0.002004  2.690960  0.018367 -0.030468  0.111409  2.187470 -0.325000
# 3  0.027195  4.082850  0.046955  0.063695  0.029225  0.672022  0.185311
# 4  0.112919  4.619220  0.126866  0.142731  0.055724  4.706800 -0.055123
#
#         f56       f57       f58       f59       f60       f61       f62  \
# 0 -0.068686 -0.108268  0.061044  0.046099  0.017113 -0.027551  0.019483
# 1  0.188196  4.960640  0.136087 -0.008493 -0.015264 -0.010841  0.064584
# 2 -0.019944  3.455030  0.068105 -0.009812 -0.010627  0.027571 -0.007121
# 3  0.164284  3.804560  0.062306 -0.021406  0.009471  0.110884  0.026837
# 4  0.524051  2.971750  0.115334  0.125205  0.067432  0.075586  0.032114
#
#         f63       f64       f65       f66       f67       f68       f69  \
# 0 -0.048826  0.050748  3.729300  5.017440  4.186880  0.063342  0.121043
# 1  0.102548  0.093611  0.964089  0.630422  4.307340  0.091289 -0.036360
# 2 -0.048914 -0.002574  1.865090  2.404170  0.411741  0.057749  0.525174
# 3  2.931160  0.068112 -0.495192  1.345280  2.242750  0.035611 -0.139274
# 4 -0.042284  0.047974 -0.294184  5.065600  1.050290  0.034019  0.024611
#
#        f70       f71       f72       f73       f74       f75       f76  \
# 0  1.37175  4.017450  0.167613  0.039753  2.042360 -0.016614  0.107679
# 1  3.61767  3.103240  0.000657  0.051302  1.924620  0.123294 -0.022671
# 2  2.16879  0.828297  0.089848  0.093744  4.949010 -0.010978  0.076671
# 3  4.74243  3.292740  0.117877  0.065605  0.556711 -0.058029  0.070501
# 4  3.12578  2.262840  0.082462 -0.023296  5.615850  0.086238  0.157568
#
#         f77       f78       f79       f80       f81      f82       f83  \
# 0  3.507250  0.013660 -0.097023  5.396070  0.244457  3.49184  0.113090
# 1  1.548120 -0.010397  0.058330  3.661310 -0.118386  2.35739 -0.009112
# 2  0.266784  0.038691  0.382731  3.847600 -0.121482  3.74084  0.147098
# 3  1.101250  0.068559  0.162928  4.070180 -0.008835  3.89678  0.913739
# 4  3.725670  0.061247  0.086603  0.607246  1.411090  2.06062 -0.023154
#
#         f84       f85       f86       f87       f88       f89       f90  \
# 0 -0.015472  4.208790  4.106560  0.037227 -0.118814  0.067086  0.010739
# 1  0.178701  4.097350  3.532890  0.005244  0.121381  0.109968  0.135838
# 2 -0.016566  0.614651  2.125840  0.078828  0.979808  0.026758  0.117310
# 3 -0.163204  3.074850  4.356780 -0.048894  4.917990  0.069930 -0.015347
# 4  0.011234  2.155530  0.914518  0.044521  0.375731  0.134351  0.013781
#
#        f91       f92       f93       f94       f95       f96      f97  \
# 0  1.09862  0.013331 -0.011715  0.052759  0.065400  4.211250  1.97877
# 1  3.46017  0.017054  0.124863  0.154064  0.606848 -0.267928  2.57786
# 2  4.88300  0.085222  0.032396  0.116092 -0.001688 -0.520069  2.14112
# 3  3.47439 -0.017103 -0.008100  0.062013  0.041193  0.511657  1.96860
# 4  1.91059 -0.042943  0.105616  0.125072  0.037509  1.043790  1.07481
#
#         f98       f99  target
# 0  0.085974  0.240496       0
# 1 -0.020877  0.024719       0
# 2  0.124464  0.148209       0
# 3  0.040017  0.044873       0
# 4 -0.012819  0.072798       1

# %%
test.head()
# Out:
#        id        f0        f1       f2        f3        f4        f5  \
# 0  600000  0.003229  4.838660  585.529  2.282910  0.713180  3.907830
# 1  600001  0.008602  0.505536 -100.099  3.012670  0.027199  1.194610
# 2  600002  1.461000  2.437260 -112.964  3.541230  0.752338  4.338310
# 3  600003  0.140556  3.085610  179.451  0.573945  0.057342  2.216790
# 4  600004  0.128876  5.199760  107.466 -0.497149  0.080220  0.458121
#
#          f6        f7        f8        f9       f10       f11       f12  \
# 0  0.480696  1.482270  4.891810  0.056351  4.200990  3.151800  0.000349
# 1  5.036620  2.517440  4.553890  0.063876  0.337257  4.439690  0.013188
# 2  1.648080  4.699910  1.950250  0.005303  2.071680  0.546499  0.141781
# 3  1.623480  0.526174  1.542540 -0.026160  1.609440  1.723560 -0.019564
# 4  0.629839  5.240460 -0.232279  0.030006  0.481359  2.176020  0.193162
#
#        f13      f14       f15       f16       f17      f18       f19  \
# 0  1.85116  2.63889  0.746668 -0.004756  1.610300  4.11482 -0.077756
# 1  3.37901  3.38470  1.167400  2.246550  1.750170  2.76624 -0.058501
# 2  1.67317  4.30649  1.702330 -0.062869  1.619230  4.19053  0.055140
# 3  1.55213  4.83264  1.501640  0.192669  4.614890  1.47069 -0.010031
# 4  1.39209  2.51890  2.993170  4.170910  0.318375  4.84563  0.085064
#
#         f20       f21       f22       f23       f24       f25      f26  \
# 0  0.129446  0.053324  0.416789  0.445009  0.150464  5.021300  2.22139
# 1  0.012595  0.036144  0.769057  0.017496  0.050283  0.324697  4.94864
# 2 -0.016590  0.017805  3.064810  0.070370  0.098316  3.507540  1.06910
# 3  0.072805  0.048035  3.230210 -0.031548  0.028697  3.752520  4.94847
# 4  0.026443 -0.004559  0.120327 -0.008630  0.004495  4.921700  1.68564
#
#         f27       f28      f29       f30       f31       f32       f33  \
# 0 -0.072333 -0.215874  1.56236  0.074881  0.010050  0.018582  0.067466
# 1  0.124789  0.347128  1.24512  0.035822 -0.013188  0.023194  0.006444
# 2  0.012750  0.009981  3.46781  0.035920 -0.009804  0.065728 -0.004725
# 3 -0.174542 -0.033491  2.47823  0.068129  0.090797  0.029877  0.146718
# 4  0.095628  0.189131  2.56955  0.046643  0.111462  0.002912  0.060737
#
#        f34       f35       f36       f37      f38       f39       f40  \
# 0  5.57830   3.08556  3.842470  0.011125  2.35997  0.695092 -0.345747
# 1  4.98333  23.70690  8.287290  4.796230  1.79928 -0.050040  1.973320
# 2  5.28102  11.52880  0.171694  4.394570  2.52084  0.079365  5.451320
# 3  3.16983 -12.98460  3.135210  1.765010  3.25399  0.713238  3.729920
# 4  4.25300  38.70340  0.170825 -0.598784  3.92796  0.262956  5.190270
#
#        f41       f42      f43      f44       f45       f46       f47  \
# 0  4.38817  0.054919  2.80360  3.87234  3.974520  0.157887  0.704785
# 1  1.91201  0.035974  2.57237  6.32126  0.442628  0.148115  1.311350
# 2  1.78582  0.029620  3.06383  5.27599  0.315972  0.148310  0.463193
# 3  2.65153  0.080945  1.05649  1.45260  1.814190  0.077875  2.721310
# 4  1.99354 -0.007611  1.09235  1.64661  5.144700  0.173642  1.156500
#
#         f48       f49      f50       f51       f52       f53      f54  \
# 0 -0.001126 -0.004548  1.01082  0.094506  0.016935  0.100871  4.36695
# 1  0.106667  0.626128  2.30973 -0.044350  0.194283  0.131445  4.26667
# 2 -0.039962  0.150592  3.75460  0.024164  0.107455  0.048741  3.58240
# 3  0.004530  0.108844  2.83445  0.024642 -0.051423  0.060574  3.42020
# 4 -0.016784 -0.045914  1.29085  0.058223 -0.147922  0.104325  3.69047
#
#         f55       f56       f57       f58       f59       f60       f61  \
# 0  1.832040  0.019682  1.964200  0.120581  0.080247  0.027516  0.048825
# 1  0.715653  0.017117  2.839080  0.104712 -0.007952  0.067650  0.066438
# 2  0.966391 -0.058947  1.869830  0.029872 -0.044294  0.065172 -0.003328
# 3  1.283600 -0.083213  0.048820 -0.002502  0.051387  0.075775 -0.008900
# 4  1.456270  0.008108  0.635948  0.039901 -0.059999  0.123505  0.011181
#
#         f62       f63       f64       f65      f66       f67       f68  \
# 0  0.074626  0.041264  0.069319  4.248810  2.09195  0.695042  0.007464
# 1  0.034258  0.606144  0.019988 -0.456704  3.37877  1.900050  0.052316
# 2 -0.001950  0.095007  0.080267  3.337300  3.60489  4.694580  0.075650
# 3  0.141776  0.173123  0.012894  3.390590  2.69899  0.059916  0.055400
# 4  0.152410  0.118767 -0.054951  4.841230  3.39522  3.737320  0.053328
#
#         f69       f70       f71       f72       f73       f74       f75  \
# 0 -0.017882  1.883500  1.268030  0.023747  0.043071  3.174780  0.074356
# 1 -0.050397  2.612950  3.112540  0.022305  0.108325  4.617640  0.091440
# 2 -0.088276  1.772440 -0.142226  0.000918  0.021483  0.241844  0.067591
# 3 -0.000140  2.641440  0.839721 -0.026268  0.058745  2.521910  0.118737
# 4  0.143619 -0.156581 -0.257201  0.987785  0.038284  2.765120  0.040994
#
#         f76       f77       f78       f79      f80       f81      f82  \
# 0  0.125909  3.926430  0.046914 -0.042290  3.01925  0.089564  3.20070
# 1  0.039368  3.035190  1.023050 -0.020578  2.77156  3.309480  5.05840
# 2 -0.026572  0.894909  0.111606  0.524423  1.45007  0.019355  1.27135
# 3  0.134899  2.839480  0.108751 -0.015848  1.14724  0.390064  3.30923
# 4  0.173981  1.112190 -0.030675  0.137178  1.55014  0.401083  1.74053
#
#         f83       f84       f85      f86       f87       f88       f89  \
# 0  0.009679 -0.099653  3.573060  4.79727  0.091985  0.773543  0.073380
# 1 -0.003993  0.067636  0.995391  2.47165 -0.015214  0.263423 -0.021910
# 2  0.076042  0.446993  4.406990  2.44697 -0.041154  0.212414  0.141005
# 3 -0.046117 -0.206052  2.373770  3.15941  0.131234  1.031180  0.026155
# 4  0.096331  0.445268  4.392460  2.52818 -0.037385  0.117148 -0.010128
#
#         f90       f91       f92       f93       f94       f95       f96  \
# 0  0.112910  1.073550  0.122149  0.086330  0.036010  0.010619  0.290343
# 1 -0.020214  2.622340  0.123307  0.033063  0.123059  0.005771 -0.392923
# 2 -0.011036  2.030180 -0.000426  0.084091  0.123605  0.499554  4.054650
# 3  0.050117  0.221613  0.045298  0.129966  0.004015  0.018279  2.696580
# 4  0.058860  2.660430  0.135425  0.036481  0.093912  0.056315  1.110710
#
#         f97       f98       f99
# 0  1.898200  0.131533  0.012047
# 1  3.689640  0.047418  0.120015
# 2  3.330670  0.108843  0.064687
# 3 -0.533491  0.052524  0.011058
# 4  3.584470  0.145319 -0.050393

# %%
print(train[train['target']==1]['target'].value_counts())
print(train[train['target']==0]['target'].value_counts())
# Out:
# 1    303606
# Name: target, dtype: int64
# 0    296394
# Name: target, dtype: int64

# %%
train.drop('id',axis=1,inplace=True)
test.drop('id',axis=1,inplace=True)

# %% [markdown]
# # OBSERVATIONS
# 1. **No null value is present in the dataset**
# 2. **data has 102 columns/features including target**
# 3. **all 100 features are float variables**
# 4. **The given problem is of binary classification.**

# %%
# cont_features

# %%
# here i have just plotted down first  6 features you can try all of them it will take a lot of time though due to large amount of features
cont_features=list(test.columns)
print("Feature distribution of continous features: ")
ncols = 3
nrows = 2

fig, axes = plt.subplots(nrows, ncols, figsize=(40,10), facecolor='#EAEAF2')

for r in range(nrows):
    for c in range(ncols):
        col = cont_features[r*ncols+c]
        sns.kdeplot(x=train[col], ax=axes[r, c], color='#58D68D', label='Train data')
        sns.kdeplot(x=test[col], ax=axes[r, c], color='#DE3163', label='Test data')
        axes[r, c].set_ylabel('')
        axes[r, c].set_xlabel(col, fontsize=15, fontweight='bold')
        axes[r, c].tick_params(labelsize=10, width=0.5)
        axes[r, c].xaxis.offsetText.set_fontsize(20)
        axes[r, c].yaxis.offsetText.set_fontsize(20)
plt.show()
# Out:
# Feature distribution of continous features:

# %% [markdown]
# **INFERENCE**
# *  **curves of both train and test look similar (good point) our cv will correlate with LB better.**

# %% [markdown]
# # **IMPORT TENSORFLOW KERAS LIBRARIES**
#
# Here i have define 2 things:
#
# * early stopping:if the model auc doesn't improve for 20 iterations training of that particular model will be stop
#
# * Reduce learning rate when a metric has stopped improving. Models often benefit from reducing the learning rate by a factor of 0.2 once learning stagnates. This callback monitors a quantity and if no improvement is seen for a 'patience' number of epochs, the learning rate is reduced.

# %%
#import libraries
from numpy.random import seed
seed(42)
import tensorflow as tf
tf.random.set_seed(42)
from tensorflow import keras
import numpy as np
from keras import backend as K
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
es = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=20, verbose=0,
    mode='min',restore_best_weights=True)


plateau = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.2, patience=5, verbose=0,
    mode='min')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-5a6dd9c21779> in <module>
#       2 from numpy.random import seed
#       3 seed(42)
# ----> 4 import tensorflow as tf
#       5 tf.random.set_seed(42)
#       6 from tensorflow import keras
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
train.var()
# Out:
# f0             0.272954
# f1             2.414971
# f2        304421.323062
# f3             2.385571
# f4             0.174297
# f5             2.441492
# f6             2.446095
# f7             2.400520
# f8             2.350051
# f9             0.177993
# f10            2.574063
# f11            2.387694
# f12            0.044462
# f13            2.303396
# f14            2.196224
# f15            2.344165
# f16            1.812663
# f17            2.488368
# f18            2.376442
# f19            0.156272
# f20            0.095443
# f21            0.003003
# f22            2.422679
# f23            0.111282
# f24            0.117222
# f25            2.590726
# f26            2.458283
# f27            0.013026
# f28            0.115138
# f29            2.323581
# f30            0.087950
# f31            0.169984
# f32            0.194142
# f33            0.012026
# f34            2.454147
# f35        16934.569516
# f36            3.188767
# f37            2.441424
# f38            2.471430
# f39            0.906098
# f40            2.458392
# f41            2.362562
# f42            0.126769
# f43            2.481099
# f44           29.314188
# f45            2.432867
# f46            0.133536
# f47            2.256052
# f48            0.085836
# f49            0.387650
# f50            2.595400
# f51            0.116690
# f52            0.336008
# f53            0.040658
# f54            2.351777
# f55            2.205888
# f56            0.726496
# f57            2.347378
# f58            0.348225
# f59            0.187002
# f60            0.023102
# f61            0.142855
# f62            0.171429
# f63            0.388143
# f64            0.046659
# f65            2.299294
# f66            2.445534
# f67            2.347996
# f68            0.159199
# f69            0.554354
# f70            2.481355
# f71            2.377370
# f72            0.095057
# f73            0.002415
# f74            2.291020
# f75            0.411918
# f76            1.455103
# f77            2.427023
# f78            0.060385
# f79            0.356206
# f80            2.486279
# f81            1.783857
# f82            2.380156
# f83            0.087516
# f84            5.589874
# f85            2.446636
# f86            2.393034
# f87            0.316102
# f88            0.987237
# f89            0.016540
# f90            0.012691
# f91            2.379334
# f92            0.300739
# f93            0.014262
# f94            0.213458
# f95            0.043734
# f96            2.428695
# f97            2.325903
# f98            0.190262
# f99            0.070170
# target         0.249964
# dtype: float64

# %% [markdown]
# # **Quantile Transformation**
# Transform features using quantiles information.
#
# This method transforms the features to follow a uniform or a normal distribution. Therefore, for a given feature, this transformation tends to spread out the most frequent values. It also reduces the impact of (marginal) outliers: this is therefore a robust preprocessing scheme.
#
# The transformation is applied on each feature independently. First an estimate of the cumulative distribution function of a feature is used to map the original values to a uniform distribution. The obtained values are then mapped to the desired output distribution using the associated quantile function. Features values of new/unseen data that fall below or above the fitted range will be mapped to the bounds of the output distribution. Note that this transform is non-linear. It may distort linear correlations between variables measured at the same scale but renders variables measured at different scales more directly comparable.

# %% [markdown]
# **Uncomment the last 6 lines if you want to try exploring Quantile transformer**

# %%
colNames=[col for col in test.columns if col not in 'id','f2','f35','f44']
# colNames.remove('id')
train.replace([np.inf, -np.inf], np.nan,inplace=True)
test.replace([np.inf, -np.inf], np.nan,inplace=True)
train_nn=train[colNames].copy()
test_nn=test[colNames].copy()
train_nn=pd.concat([train_nn,test_nn])
# for col in colNames:
#     #print(col)
#     qt = QuantileTransformer(random_state=21,n_quantiles=2000, output_distribution='normal')
#     train_nn[col] = qt.fit_transform(train_nn[[col]])
#     test_nn[col] = qt.transform(test_nn[[col]])    
# test_nn=train_nn[-test_nn.shape[0]:]
# train_nn=train_nn[:-test_nn.shape[0]]
# Out:
#   File "/tmp/ipykernel_35/4203430911.py", line 1
#     colNames=[col for col in test.columns if col not in 'id','f2','f35','f44']
#                                                             ^
# SyntaxError: invalid syntax

# %%
train_nn['target']=train['target']

# %% [markdown]
# # **KEY POINTS:**
# * **Swish Activation**:The choice of activation functions in Deep Neural Networks has a significant impact on the training dynamics and task performance. Currently, the most successful and widely-used activation function is the Rectified Linear Unit (ReLU), which is f(x)=max(0,x). Although various alternatives to ReLU have been proposed, none have managed to replace it due to inconsistent gains. So Google Brain Team has proposed a new activation function, named Swish, which is simply f(x) = x · sigmoid(x). Their experiments show that Swish tends to work better than ReLU on deeper models across a number of challenging datasets.
#
# ![image.png](attachment:aa68cdce-9fee-422e-a1e0-ead3785b705e.png)
#
# * **Input Layer** : every neural network has an input layer, we have passed shape=(100,) to it since there are 100 features in our data.
#
# * **Hidden Layers** :In neural networks, a hidden layer is located between the input and output of the algorithm, in which the function applies weights to the inputs and directs them through an activation function as the output. In short, the hidden layers perform nonlinear transformations of the inputs entered into the network. here we have three hidden layers of units (100,64,32) units.
#
# * **Output Layers** :There must always be one output layer in a neural network. The output layer takes in the inputs which are passed in from the layers before it, performs the calculations via its neurons and then the output is computed. here we have used sigmoid activation.Image below is the diagram of sigmid activation.
#
# ![image.png](attachment:7e2ce760-5f4a-432a-ae88-1fe400f68eab.png)

# %%
#https://bignerdranch.com/blog/implementing-swish-activation-function-in-keras/
from keras.backend import sigmoid
from sklearn.metrics import roc_auc_score
def swish(x, beta = 1):
    return (x * sigmoid(beta * x))

from keras.utils.generic_utils import get_custom_objects
from keras.layers import Activation
get_custom_objects().update({'swish': Activation(swish)})

hidden_units = (128,64,32)#initialized number of neurons in each hidden layer

def base_model():

    num_input = keras.Input(shape=(test.shape[1],), name='num_data')#input layer


    out = keras.layers.Concatenate()([num_input])
    
    # Add one or more hidden layers
    for n_hidden in hidden_units:

        out = keras.layers.Dense(n_hidden, activation='swish')(out)

    #out = keras.layers.Concatenate()([out, num_input])

    # A single output: our predicted target value probability
    out = keras.layers.Dense(1, activation='sigmoid', name='prediction')(out)
    
    model = keras.Model(
    inputs = [num_input],
    outputs = out,
    )
    
    return model

# %% [markdown]
# # **Key points:**
#
# *  **Validation strategy**: here i have used Kfold strategy, the data is divided into 5 folds , 4 of them are used for training and 1 of them is used for validation this will happen 5 times.
# * **Loss=binary cross entropy**: for understanding this you can refer this link :https://towardsdatascience.com/understanding-binary-cross-entropy-log-loss-a-visual-explanation-a3ac6025181a
# ![image.png](attachment:a780c9e1-1c64-4292-ba2e-7493ee12d7bf.png)
# * **Metrics=AUC**:This is the metrics we have to use in this competition.
#
# * **Batch size**:Batch size is a term used in machine learning and refers to the number of training examples utilized in one iteration. so our training examples are going into our network in batches here specifically they are going in the batches of 2048, you can try tweaking it and check what happens if we change it.

# %%
target_name='target'
scores_folds = {}
model_name = 'NN'
pred_name = 'pred_{}'.format(model_name)

n_folds = 5
kf = model_selection.StratifiedKFold(n_splits=n_folds, shuffle=True, random_state=2020)
scores_folds[model_name] = []
counter = 1

features_to_consider = list(train_nn)

features_to_consider.remove('target')
try:
    features_to_consider.remove('pred_NN')
except:
    pass


train_nn[features_to_consider] = train_nn[features_to_consider].fillna(train_nn[features_to_consider].mean())
test_nn[features_to_consider] = test_nn[features_to_consider].fillna(train_nn[features_to_consider].mean())

train_nn[pred_name] = 0
test_nn[target_name] = 0
test_predictions_nn = np.zeros(test_nn.shape[0])

for fold, (trn_ind, val_ind) in enumerate(kf.split(train,train['target'])):
    print(f'Training fold {fold + 1}')
    X_train, X_test = train_nn.iloc[trn_ind][features_to_consider], train_nn.iloc[val_ind][features_to_consider]
    y_train, y_test = train_nn.iloc[trn_ind]['target'], train_nn.iloc[val_ind]['target']
    print('CV {}/{}'.format(counter, n_folds)) 
    #############################################################################################
    # NN
    #############################################################################################
    
    model = base_model()
    
    model.compile(
        keras.optimizers.Adam(learning_rate=0.001),
#          keras.optimizers.Nadam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07),
        loss='binary_crossentropy',
        metrics = ['AUC']
    )
    
    num_data = X_train[features_to_consider]
    
    scaler = MinMaxScaler(feature_range=(0, 1))         
    num_data = scaler.fit_transform(num_data.values)    
      
    target =  y_train
    
    num_data_test = X_test[features_to_consider]
    num_data_test = scaler.transform(num_data_test.values)

    model.fit([num_data], 
              target,               
              batch_size=2048,
              epochs=1000,
              validation_data=([num_data_test], y_test),
              callbacks=[es, plateau],
              validation_batch_size=len(y_test),
              shuffle=True,
             verbose = 1)

    preds = model.predict([num_data_test]).reshape(1,-1)[0]
    score = round(roc_auc_score(y_test,preds),5)
    print('Fold {} {}: {}'.format(counter, model_name, score))
    scores_folds[model_name].append(score)
    
    tt =scaler.transform(test_nn[features_to_consider].values)
    
    test_predictions_nn += model.predict([tt]).reshape(1,-1)[0].clip(0,1e10)/n_folds       
    counter += 1
# Out:
# Training fold 1
# CV 1/5
# Epoch 1/1000
# 235/235 [==============================] - 3s 8ms/step - loss: 0.6296 - auc: 0.7154 - val_loss: 0.6149 - val_auc: 0.7356
# Epoch 2/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.6155 - auc: 0.7336 - val_loss: 0.6132 - val_auc: 0.7402
# Epoch 3/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.6141 - auc: 0.7360 - val_loss: 0.6125 - val_auc: 0.7424
# Epoch 4/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.6123 - auc: 0.7388 - val_loss: 0.6098 - val_auc: 0.7441
# Epoch 5/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.6120 - auc: 0.7392 - val_loss: 0.6082 - val_auc: 0.7450
# Epoch 6/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.6094 - auc: 0.7410 - val_loss: 0.6033 - val_auc: 0.7452
# Epoch 7/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5992 - auc: 0.7399 - val_loss: 0.5898 - val_auc: 0.7447
# Epoch 8/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5914 - auc: 0.7426 - val_loss: 0.5871 - val_auc: 0.7458
# Epoch 9/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5890 - auc: 0.7440 - val_loss: 0.5900 - val_auc: 0.7468
# Epoch 10/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5876 - auc: 0.7450 - val_loss: 0.5865 - val_auc: 0.7476
# Epoch 11/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5872 - auc: 0.7451 - val_loss: 0.5830 - val_auc: 0.7485
# Epoch 12/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5858 - auc: 0.7459 - val_loss: 0.5889 - val_auc: 0.7487
# Epoch 13/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5838 - auc: 0.7471 - val_loss: 0.5842 - val_auc: 0.7489
# Epoch 14/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5840 - auc: 0.7473 - val_loss: 0.5805 - val_auc: 0.7498
# Epoch 15/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5833 - auc: 0.7476 - val_loss: 0.5875 - val_auc: 0.7489
# Epoch 16/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5819 - auc: 0.7483 - val_loss: 0.5812 - val_auc: 0.7505
# Epoch 17/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5828 - auc: 0.7477 - val_loss: 0.5804 - val_auc: 0.7502
# Epoch 18/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5809 - auc: 0.7492 - val_loss: 0.5792 - val_auc: 0.7504
# Epoch 19/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5799 - auc: 0.7496 - val_loss: 0.5778 - val_auc: 0.7508
# Epoch 20/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5802 - auc: 0.7494 - val_loss: 0.5807 - val_auc: 0.7509
# Epoch 21/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5791 - auc: 0.7499 - val_loss: 0.5851 - val_auc: 0.7510
# Epoch 22/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5792 - auc: 0.7500 - val_loss: 0.5811 - val_auc: 0.7514
# Epoch 23/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5799 - auc: 0.7499 - val_loss: 0.5829 - val_auc: 0.7511
# Epoch 24/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5800 - auc: 0.7496 - val_loss: 0.5907 - val_auc: 0.7510
# Epoch 25/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5771 - auc: 0.7515 - val_loss: 0.5757 - val_auc: 0.7516
# Epoch 26/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5764 - auc: 0.7518 - val_loss: 0.5770 - val_auc: 0.7515
# Epoch 27/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5765 - auc: 0.7519 - val_loss: 0.5759 - val_auc: 0.7516
# Epoch 28/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5764 - auc: 0.7518 - val_loss: 0.5768 - val_auc: 0.7517
# Epoch 29/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5762 - auc: 0.7519 - val_loss: 0.5753 - val_auc: 0.7517
# Epoch 30/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5761 - auc: 0.7519 - val_loss: 0.5752 - val_auc: 0.7518
# Epoch 31/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5763 - auc: 0.7520 - val_loss: 0.5754 - val_auc: 0.7518
# Epoch 32/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5761 - auc: 0.7520 - val_loss: 0.5752 - val_auc: 0.7517
# Epoch 33/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5758 - auc: 0.7522 - val_loss: 0.5748 - val_auc: 0.7519
# Epoch 34/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5758 - auc: 0.7521 - val_loss: 0.5747 - val_auc: 0.7518
# Epoch 35/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5756 - auc: 0.7522 - val_loss: 0.5763 - val_auc: 0.7519
# Epoch 36/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5757 - auc: 0.7521 - val_loss: 0.5750 - val_auc: 0.7519
# Epoch 37/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5753 - auc: 0.7523 - val_loss: 0.5764 - val_auc: 0.7522
# Epoch 38/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5762 - auc: 0.7517 - val_loss: 0.5768 - val_auc: 0.7519
# Epoch 39/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5750 - auc: 0.7526 - val_loss: 0.5744 - val_auc: 0.7520
# Epoch 40/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5749 - auc: 0.7526 - val_loss: 0.5747 - val_auc: 0.7519
# Epoch 41/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5748 - auc: 0.7527 - val_loss: 0.5742 - val_auc: 0.7520
# Epoch 42/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5749 - auc: 0.7527 - val_loss: 0.5744 - val_auc: 0.7521
# Epoch 43/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5748 - auc: 0.7527 - val_loss: 0.5751 - val_auc: 0.7519
# Epoch 44/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5748 - auc: 0.7527 - val_loss: 0.5742 - val_auc: 0.7520
# Epoch 45/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5748 - auc: 0.7527 - val_loss: 0.5742 - val_auc: 0.7519
# Epoch 46/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5748 - auc: 0.7527 - val_loss: 0.5743 - val_auc: 0.7519
# Epoch 47/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5746 - auc: 0.7529 - val_loss: 0.5741 - val_auc: 0.7520
# Epoch 48/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5746 - auc: 0.7528 - val_loss: 0.5741 - val_auc: 0.7519
# Epoch 49/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5746 - auc: 0.7529 - val_loss: 0.5742 - val_auc: 0.7520
# Epoch 50/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5746 - auc: 0.7528 - val_loss: 0.5741 - val_auc: 0.7520
# Epoch 51/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5746 - auc: 0.7528 - val_loss: 0.5741 - val_auc: 0.7520
# Epoch 52/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5746 - auc: 0.7529 - val_loss: 0.5741 - val_auc: 0.7520
# Epoch 53/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5745 - auc: 0.7529 - val_loss: 0.5741 - val_auc: 0.7520
# Epoch 54/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5745 - auc: 0.7529 - val_loss: 0.5741 - val_auc: 0.7520
# Epoch 55/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5745 - auc: 0.7529 - val_loss: 0.5741 - val_auc: 0.7521
# Epoch 56/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5745 - auc: 0.7529 - val_loss: 0.5741 - val_auc: 0.7520
# Epoch 57/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5745 - auc: 0.7529 - val_loss: 0.5741 - val_auc: 0.7520
# Epoch 58/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5745 - auc: 0.7529 - val_loss: 0.5741 - val_auc: 0.7520
# Epoch 59/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5745 - auc: 0.7529 - val_loss: 0.5741 - val_auc: 0.7520
# Epoch 60/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5745 - auc: 0.7529 - val_loss: 0.5741 - val_auc: 0.7520
# Epoch 61/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5745 - auc: 0.7529 - val_loss: 0.5741 - val_auc: 0.7520
# Epoch 62/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5745 - auc: 0.7529 - val_loss: 0.5741 - val_auc: 0.7520
# Epoch 63/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5745 - auc: 0.7529 - val_loss: 0.5741 - val_auc: 0.7521
# Epoch 64/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5745 - auc: 0.7529 - val_loss: 0.5741 - val_auc: 0.7521
# Epoch 65/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5745 - auc: 0.7529 - val_loss: 0.5741 - val_auc: 0.7521
# Epoch 66/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5745 - auc: 0.7529 - val_loss: 0.5741 - val_auc: 0.7521
# Epoch 67/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5745 - auc: 0.7529 - val_loss: 0.5741 - val_auc: 0.7521
# Epoch 68/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5745 - auc: 0.7529 - val_loss: 0.5741 - val_auc: 0.7521
# Epoch 69/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5745 - auc: 0.7529 - val_loss: 0.5741 - val_auc: 0.7521
# Epoch 70/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5745 - auc: 0.7529 - val_loss: 0.5741 - val_auc: 0.7521
# Epoch 71/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5745 - auc: 0.7529 - val_loss: 0.5741 - val_auc: 0.7521
# Epoch 72/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5745 - auc: 0.7529 - val_loss: 0.5741 - val_auc: 0.7521
# Epoch 73/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5745 - auc: 0.7529 - val_loss: 0.5741 - val_auc: 0.7521
# Epoch 74/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5745 - auc: 0.7529 - val_loss: 0.5741 - val_auc: 0.7521
# Epoch 75/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5745 - auc: 0.7529 - val_loss: 0.5741 - val_auc: 0.7521
# Epoch 76/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5745 - auc: 0.7529 - val_loss: 0.5741 - val_auc: 0.7521
# Epoch 77/1000
# 235/235 [==============================] - 2s 6ms/step - loss: 0.5745 - auc: 0.7529 - val_loss: 0.5741 - val_auc: 0.7521
# Epoch 78/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5745 - auc: 0.7529 - val_loss: 0.5741 - val_auc: 0.7521
# Epoch 79/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5745 - auc: 0.7529 - val_loss: 0.5741 - val_auc: 0.7521
# Fold 1 NN: 0.75202
# Training fold 2
# CV 2/5
# Epoch 1/1000
# 235/235 [==============================] - 3s 7ms/step - loss: 0.6303 - auc: 0.7141 - val_loss: 0.6153 - val_auc: 0.7340
# Epoch 2/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.6162 - auc: 0.7323 - val_loss: 0.6171 - val_auc: 0.7385
# Epoch 3/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.6128 - auc: 0.7374 - val_loss: 0.6101 - val_auc: 0.7416
# Epoch 4/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.6079 - auc: 0.7387 - val_loss: 0.6015 - val_auc: 0.7424
# Epoch 5/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5984 - auc: 0.7389 - val_loss: 0.5928 - val_auc: 0.7430
# Epoch 6/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5958 - auc: 0.7397 - val_loss: 0.5904 - val_auc: 0.7440
# Epoch 7/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5912 - auc: 0.7433 - val_loss: 0.5882 - val_auc: 0.7450
# Epoch 8/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5896 - auc: 0.7444 - val_loss: 0.5910 - val_auc: 0.7452
# Epoch 9/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5889 - auc: 0.7446 - val_loss: 0.5893 - val_auc: 0.7469
# Epoch 10/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5887 - auc: 0.7447 - val_loss: 0.5847 - val_auc: 0.7467
# Epoch 11/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5861 - auc: 0.7464 - val_loss: 0.5836 - val_auc: 0.7470
# Epoch 12/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5846 - auc: 0.7472 - val_loss: 0.5823 - val_auc: 0.7480
# Epoch 13/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5840 - auc: 0.7478 - val_loss: 0.5870 - val_auc: 0.7474
# Epoch 14/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5839 - auc: 0.7478 - val_loss: 0.5829 - val_auc: 0.7490
# Epoch 15/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5833 - auc: 0.7477 - val_loss: 0.5813 - val_auc: 0.7491
# Epoch 16/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5827 - auc: 0.7484 - val_loss: 0.5802 - val_auc: 0.7492
# Epoch 17/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5822 - auc: 0.7488 - val_loss: 0.5812 - val_auc: 0.7494
# Epoch 18/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5810 - auc: 0.7494 - val_loss: 0.5793 - val_auc: 0.7502
# Epoch 19/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5807 - auc: 0.7493 - val_loss: 0.5927 - val_auc: 0.7496
# Epoch 20/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5802 - auc: 0.7496 - val_loss: 0.5780 - val_auc: 0.7504
# Epoch 21/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5796 - auc: 0.7499 - val_loss: 0.5778 - val_auc: 0.7503
# Epoch 22/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5789 - auc: 0.7503 - val_loss: 0.5776 - val_auc: 0.7505
# Epoch 23/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5783 - auc: 0.7509 - val_loss: 0.5809 - val_auc: 0.7507
# Epoch 24/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5779 - auc: 0.7510 - val_loss: 0.5761 - val_auc: 0.7506
# Epoch 25/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5780 - auc: 0.7508 - val_loss: 0.5769 - val_auc: 0.7503
# Epoch 26/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5771 - auc: 0.7512 - val_loss: 0.5757 - val_auc: 0.7516
# Epoch 27/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5774 - auc: 0.7511 - val_loss: 0.5748 - val_auc: 0.7508
# Epoch 28/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5770 - auc: 0.7512 - val_loss: 0.5819 - val_auc: 0.7513
# Epoch 29/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5772 - auc: 0.7514 - val_loss: 0.5779 - val_auc: 0.7506
# Epoch 30/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5761 - auc: 0.7519 - val_loss: 0.5745 - val_auc: 0.7509
# Epoch 31/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5762 - auc: 0.7518 - val_loss: 0.5751 - val_auc: 0.7523
# Epoch 32/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5765 - auc: 0.7515 - val_loss: 0.5735 - val_auc: 0.7515
# Epoch 33/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5746 - auc: 0.7522 - val_loss: 0.5745 - val_auc: 0.7520
# Epoch 34/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5763 - auc: 0.7517 - val_loss: 0.5774 - val_auc: 0.7515
# Epoch 35/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5748 - auc: 0.7522 - val_loss: 0.5793 - val_auc: 0.7520
# Epoch 36/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5752 - auc: 0.7526 - val_loss: 0.5731 - val_auc: 0.7524
# Epoch 37/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5755 - auc: 0.7523 - val_loss: 0.5768 - val_auc: 0.7524
# Epoch 38/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5747 - auc: 0.7527 - val_loss: 0.5825 - val_auc: 0.7514
# Epoch 39/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5749 - auc: 0.7523 - val_loss: 0.5738 - val_auc: 0.7518
# Epoch 40/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5740 - auc: 0.7528 - val_loss: 0.5736 - val_auc: 0.7516
# Epoch 41/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5732 - auc: 0.7533 - val_loss: 0.5723 - val_auc: 0.7520
# Epoch 42/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5746 - auc: 0.7525 - val_loss: 0.5939 - val_auc: 0.7518
# Epoch 43/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5750 - auc: 0.7525 - val_loss: 0.5725 - val_auc: 0.7526
# Epoch 44/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5743 - auc: 0.7528 - val_loss: 0.5717 - val_auc: 0.7528
# Epoch 45/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5735 - auc: 0.7531 - val_loss: 0.5722 - val_auc: 0.7519
# Epoch 46/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5732 - auc: 0.7535 - val_loss: 0.5731 - val_auc: 0.7522
# Epoch 47/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5734 - auc: 0.7531 - val_loss: 0.5803 - val_auc: 0.7522
# Epoch 48/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5730 - auc: 0.7531 - val_loss: 0.5732 - val_auc: 0.7523
# Epoch 49/1000
# 235/235 [==============================] - 2s 6ms/step - loss: 0.5734 - auc: 0.7535 - val_loss: 0.5739 - val_auc: 0.7526
# Epoch 50/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5711 - auc: 0.7546 - val_loss: 0.5714 - val_auc: 0.7523
# Epoch 51/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5708 - auc: 0.7549 - val_loss: 0.5708 - val_auc: 0.7527
# Epoch 52/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5708 - auc: 0.7548 - val_loss: 0.5712 - val_auc: 0.7524
# Epoch 53/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5709 - auc: 0.7550 - val_loss: 0.5715 - val_auc: 0.7528
# Epoch 54/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5709 - auc: 0.7550 - val_loss: 0.5714 - val_auc: 0.7523
# Epoch 55/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5707 - auc: 0.7548 - val_loss: 0.5708 - val_auc: 0.7527
# Epoch 56/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5709 - auc: 0.7549 - val_loss: 0.5710 - val_auc: 0.7527
# Epoch 57/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5703 - auc: 0.7553 - val_loss: 0.5707 - val_auc: 0.7525
# Epoch 58/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5702 - auc: 0.7553 - val_loss: 0.5707 - val_auc: 0.7527
# Epoch 59/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5702 - auc: 0.7553 - val_loss: 0.5707 - val_auc: 0.7526
# Epoch 60/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5702 - auc: 0.7554 - val_loss: 0.5707 - val_auc: 0.7525
# Epoch 61/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5702 - auc: 0.7554 - val_loss: 0.5707 - val_auc: 0.7526
# Epoch 62/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5702 - auc: 0.7553 - val_loss: 0.5709 - val_auc: 0.7526
# Epoch 63/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5700 - auc: 0.7555 - val_loss: 0.5706 - val_auc: 0.7525
# Epoch 64/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5700 - auc: 0.7555 - val_loss: 0.5706 - val_auc: 0.7526
# Epoch 65/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5700 - auc: 0.7555 - val_loss: 0.5706 - val_auc: 0.7525
# Epoch 66/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5700 - auc: 0.7555 - val_loss: 0.5706 - val_auc: 0.7526
# Epoch 67/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5700 - auc: 0.7555 - val_loss: 0.5707 - val_auc: 0.7525
# Epoch 68/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5700 - auc: 0.7555 - val_loss: 0.5707 - val_auc: 0.7525
# Epoch 69/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5700 - auc: 0.7556 - val_loss: 0.5705 - val_auc: 0.7525
# Epoch 70/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5700 - auc: 0.7556 - val_loss: 0.5706 - val_auc: 0.7525
# Epoch 71/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5700 - auc: 0.7556 - val_loss: 0.5705 - val_auc: 0.7526
# Epoch 72/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5700 - auc: 0.7556 - val_loss: 0.5705 - val_auc: 0.7525
# Epoch 73/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5700 - auc: 0.7556 - val_loss: 0.5706 - val_auc: 0.7525
# Epoch 74/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5700 - auc: 0.7556 - val_loss: 0.5706 - val_auc: 0.7525
# Epoch 75/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5700 - auc: 0.7556 - val_loss: 0.5706 - val_auc: 0.7525
# Epoch 76/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5700 - auc: 0.7556 - val_loss: 0.5706 - val_auc: 0.7525
# Epoch 77/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5700 - auc: 0.7556 - val_loss: 0.5706 - val_auc: 0.7525
# Epoch 78/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5700 - auc: 0.7556 - val_loss: 0.5706 - val_auc: 0.7525
# Epoch 79/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5700 - auc: 0.7556 - val_loss: 0.5706 - val_auc: 0.7525
# Epoch 80/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5700 - auc: 0.7556 - val_loss: 0.5706 - val_auc: 0.7525
# Epoch 81/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5700 - auc: 0.7556 - val_loss: 0.5706 - val_auc: 0.7525
# Epoch 82/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5700 - auc: 0.7556 - val_loss: 0.5706 - val_auc: 0.7525
# Epoch 83/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5700 - auc: 0.7556 - val_loss: 0.5706 - val_auc: 0.7525
# Epoch 84/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5700 - auc: 0.7556 - val_loss: 0.5706 - val_auc: 0.7525
# Epoch 85/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5700 - auc: 0.7556 - val_loss: 0.5706 - val_auc: 0.7525
# Epoch 86/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5700 - auc: 0.7556 - val_loss: 0.5706 - val_auc: 0.7525
# Epoch 87/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5700 - auc: 0.7556 - val_loss: 0.5706 - val_auc: 0.7525
# Epoch 88/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5700 - auc: 0.7556 - val_loss: 0.5706 - val_auc: 0.7525
# Epoch 89/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5700 - auc: 0.7556 - val_loss: 0.5706 - val_auc: 0.7525
# Epoch 90/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5700 - auc: 0.7556 - val_loss: 0.5706 - val_auc: 0.7525
# Epoch 91/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5700 - auc: 0.7556 - val_loss: 0.5706 - val_auc: 0.7525
# Epoch 92/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5700 - auc: 0.7556 - val_loss: 0.5706 - val_auc: 0.7525
# Fold 2 NN: 0.75256
# Training fold 3
# CV 3/5
# Epoch 1/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.6268 - auc: 0.7198 - val_loss: 0.6300 - val_auc: 0.7334
# Epoch 2/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.6149 - auc: 0.7346 - val_loss: 0.6183 - val_auc: 0.7374
# Epoch 3/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.6135 - auc: 0.7368 - val_loss: 0.6138 - val_auc: 0.7397
# Epoch 4/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.6117 - auc: 0.7391 - val_loss: 0.6117 - val_auc: 0.7407
# Epoch 5/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.6074 - auc: 0.7402 - val_loss: 0.6021 - val_auc: 0.7403
# Epoch 6/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5971 - auc: 0.7407 - val_loss: 0.5942 - val_auc: 0.7415
# Epoch 7/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5924 - auc: 0.7426 - val_loss: 0.5944 - val_auc: 0.7429
# Epoch 8/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5897 - auc: 0.7444 - val_loss: 0.5899 - val_auc: 0.7439
# Epoch 9/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5876 - auc: 0.7456 - val_loss: 0.5884 - val_auc: 0.7451
# Epoch 10/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5868 - auc: 0.7459 - val_loss: 0.5916 - val_auc: 0.7457
# Epoch 11/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5847 - auc: 0.7471 - val_loss: 0.5855 - val_auc: 0.7467
# Epoch 12/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5837 - auc: 0.7476 - val_loss: 0.5863 - val_auc: 0.7470
# Epoch 13/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5835 - auc: 0.7478 - val_loss: 0.5826 - val_auc: 0.7476
# Epoch 14/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5827 - auc: 0.7478 - val_loss: 0.5823 - val_auc: 0.7478
# Epoch 15/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5810 - auc: 0.7493 - val_loss: 0.5849 - val_auc: 0.7483
# Epoch 16/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5798 - auc: 0.7496 - val_loss: 0.5813 - val_auc: 0.7487
# Epoch 17/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5798 - auc: 0.7496 - val_loss: 0.5807 - val_auc: 0.7491
# Epoch 18/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5786 - auc: 0.7499 - val_loss: 0.5782 - val_auc: 0.7495
# Epoch 19/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5805 - auc: 0.7492 - val_loss: 0.5786 - val_auc: 0.7497
# Epoch 20/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5795 - auc: 0.7493 - val_loss: 0.5818 - val_auc: 0.7497
# Epoch 21/1000
# 235/235 [==============================] - 2s 8ms/step - loss: 0.5790 - auc: 0.7499 - val_loss: 0.5855 - val_auc: 0.7492
# Epoch 22/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5774 - auc: 0.7509 - val_loss: 0.5773 - val_auc: 0.7502
# Epoch 23/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5767 - auc: 0.7511 - val_loss: 0.5815 - val_auc: 0.7506
# Epoch 24/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5768 - auc: 0.7510 - val_loss: 0.5811 - val_auc: 0.7505
# Epoch 25/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5770 - auc: 0.7507 - val_loss: 0.5758 - val_auc: 0.7507
# Epoch 26/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5764 - auc: 0.7510 - val_loss: 0.5787 - val_auc: 0.7504
# Epoch 27/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5755 - auc: 0.7517 - val_loss: 0.5835 - val_auc: 0.7509
# Epoch 28/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5755 - auc: 0.7513 - val_loss: 0.5761 - val_auc: 0.7509
# Epoch 29/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5755 - auc: 0.7516 - val_loss: 0.5745 - val_auc: 0.7513
# Epoch 30/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5743 - auc: 0.7517 - val_loss: 0.5751 - val_auc: 0.7514
# Epoch 31/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5752 - auc: 0.7514 - val_loss: 0.5758 - val_auc: 0.7513
# Epoch 32/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5740 - auc: 0.7520 - val_loss: 0.5758 - val_auc: 0.7513
# Epoch 33/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5741 - auc: 0.7523 - val_loss: 0.5824 - val_auc: 0.7512
# Epoch 34/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5740 - auc: 0.7521 - val_loss: 0.5813 - val_auc: 0.7509
# Epoch 35/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5715 - auc: 0.7536 - val_loss: 0.5737 - val_auc: 0.7517
# Epoch 36/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5711 - auc: 0.7540 - val_loss: 0.5738 - val_auc: 0.7519
# Epoch 37/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5712 - auc: 0.7540 - val_loss: 0.5737 - val_auc: 0.7519
# Epoch 38/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5712 - auc: 0.7542 - val_loss: 0.5746 - val_auc: 0.7520
# Epoch 39/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5712 - auc: 0.7541 - val_loss: 0.5728 - val_auc: 0.7520
# Epoch 40/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5711 - auc: 0.7541 - val_loss: 0.5726 - val_auc: 0.7519
# Epoch 41/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5707 - auc: 0.7543 - val_loss: 0.5732 - val_auc: 0.7520
# Epoch 42/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5710 - auc: 0.7543 - val_loss: 0.5731 - val_auc: 0.7521
# Epoch 43/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5710 - auc: 0.7541 - val_loss: 0.5725 - val_auc: 0.7520
# Epoch 44/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5708 - auc: 0.7543 - val_loss: 0.5738 - val_auc: 0.7520
# Epoch 45/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5706 - auc: 0.7543 - val_loss: 0.5740 - val_auc: 0.7521
# Epoch 46/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5709 - auc: 0.7541 - val_loss: 0.5734 - val_auc: 0.7524
# Epoch 47/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5707 - auc: 0.7543 - val_loss: 0.5725 - val_auc: 0.7523
# Epoch 48/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5705 - auc: 0.7545 - val_loss: 0.5763 - val_auc: 0.7521
# Epoch 49/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5699 - auc: 0.7549 - val_loss: 0.5720 - val_auc: 0.7524
# Epoch 50/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5697 - auc: 0.7552 - val_loss: 0.5719 - val_auc: 0.7524
# Epoch 51/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5697 - auc: 0.7551 - val_loss: 0.5718 - val_auc: 0.7524
# Epoch 52/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5697 - auc: 0.7551 - val_loss: 0.5719 - val_auc: 0.7525
# Epoch 53/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5696 - auc: 0.7552 - val_loss: 0.5723 - val_auc: 0.7523
# Epoch 54/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5697 - auc: 0.7552 - val_loss: 0.5719 - val_auc: 0.7524
# Epoch 55/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5696 - auc: 0.7552 - val_loss: 0.5718 - val_auc: 0.7524
# Epoch 56/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5695 - auc: 0.7553 - val_loss: 0.5718 - val_auc: 0.7524
# Epoch 57/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5695 - auc: 0.7552 - val_loss: 0.5718 - val_auc: 0.7524
# Epoch 58/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5695 - auc: 0.7552 - val_loss: 0.5718 - val_auc: 0.7525
# Epoch 59/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5695 - auc: 0.7553 - val_loss: 0.5718 - val_auc: 0.7524
# Epoch 60/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5695 - auc: 0.7553 - val_loss: 0.5718 - val_auc: 0.7525
# Epoch 61/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5695 - auc: 0.7553 - val_loss: 0.5717 - val_auc: 0.7524
# Epoch 62/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5694 - auc: 0.7553 - val_loss: 0.5717 - val_auc: 0.7524
# Epoch 63/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5694 - auc: 0.7553 - val_loss: 0.5717 - val_auc: 0.7524
# Epoch 64/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5694 - auc: 0.7553 - val_loss: 0.5717 - val_auc: 0.7524
# Epoch 65/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5694 - auc: 0.7553 - val_loss: 0.5717 - val_auc: 0.7524
# Epoch 66/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5694 - auc: 0.7553 - val_loss: 0.5717 - val_auc: 0.7524
# Epoch 67/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5694 - auc: 0.7553 - val_loss: 0.5717 - val_auc: 0.7524
# Epoch 68/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5694 - auc: 0.7553 - val_loss: 0.5717 - val_auc: 0.7524
# Epoch 69/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5694 - auc: 0.7553 - val_loss: 0.5717 - val_auc: 0.7524
# Epoch 70/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5694 - auc: 0.7553 - val_loss: 0.5717 - val_auc: 0.7524
# Epoch 71/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5694 - auc: 0.7553 - val_loss: 0.5717 - val_auc: 0.7524
# Epoch 72/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5694 - auc: 0.7553 - val_loss: 0.5717 - val_auc: 0.7524
# Epoch 73/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5694 - auc: 0.7553 - val_loss: 0.5717 - val_auc: 0.7524
# Epoch 74/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5694 - auc: 0.7553 - val_loss: 0.5717 - val_auc: 0.7524
# Epoch 75/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5694 - auc: 0.7553 - val_loss: 0.5717 - val_auc: 0.7524
# Epoch 76/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5694 - auc: 0.7553 - val_loss: 0.5717 - val_auc: 0.7524
# Epoch 77/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5694 - auc: 0.7553 - val_loss: 0.5717 - val_auc: 0.7524
# Epoch 78/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5694 - auc: 0.7553 - val_loss: 0.5717 - val_auc: 0.7524
# Epoch 79/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5694 - auc: 0.7553 - val_loss: 0.5717 - val_auc: 0.7524
# Epoch 80/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5694 - auc: 0.7553 - val_loss: 0.5717 - val_auc: 0.7524
# Epoch 81/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5694 - auc: 0.7553 - val_loss: 0.5717 - val_auc: 0.7524
# Epoch 82/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5694 - auc: 0.7553 - val_loss: 0.5717 - val_auc: 0.7524
# Epoch 83/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5694 - auc: 0.7553 - val_loss: 0.5717 - val_auc: 0.7524
# Epoch 84/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5694 - auc: 0.7553 - val_loss: 0.5717 - val_auc: 0.7524
# Epoch 85/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5694 - auc: 0.7553 - val_loss: 0.5717 - val_auc: 0.7524
# Epoch 86/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5694 - auc: 0.7553 - val_loss: 0.5717 - val_auc: 0.7524
# Epoch 87/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5694 - auc: 0.7553 - val_loss: 0.5717 - val_auc: 0.7524
# Epoch 88/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5694 - auc: 0.7553 - val_loss: 0.5717 - val_auc: 0.7524
# Epoch 89/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5694 - auc: 0.7553 - val_loss: 0.5717 - val_auc: 0.7524
# Epoch 90/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5694 - auc: 0.7553 - val_loss: 0.5717 - val_auc: 0.7524
# Fold 3 NN: 0.75248
# Training fold 4
# CV 4/5
# Epoch 1/1000
# 235/235 [==============================] - 3s 8ms/step - loss: 0.6300 - auc: 0.7146 - val_loss: 0.6167 - val_auc: 0.7325
# Epoch 2/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.6160 - auc: 0.7325 - val_loss: 0.6208 - val_auc: 0.7368
# Epoch 3/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.6136 - auc: 0.7363 - val_loss: 0.6114 - val_auc: 0.7394
# Epoch 4/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.6109 - auc: 0.7392 - val_loss: 0.6081 - val_auc: 0.7411
# Epoch 5/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.6024 - auc: 0.7397 - val_loss: 0.5973 - val_auc: 0.7404
# Epoch 6/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5950 - auc: 0.7406 - val_loss: 0.5919 - val_auc: 0.7424
# Epoch 7/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5914 - auc: 0.7430 - val_loss: 0.6024 - val_auc: 0.7434
# Epoch 8/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5911 - auc: 0.7431 - val_loss: 0.5880 - val_auc: 0.7450
# Epoch 9/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5879 - auc: 0.7452 - val_loss: 0.5903 - val_auc: 0.7458
# Epoch 10/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5876 - auc: 0.7455 - val_loss: 0.5867 - val_auc: 0.7468
# Epoch 11/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5861 - auc: 0.7463 - val_loss: 0.5910 - val_auc: 0.7470
# Epoch 12/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5851 - auc: 0.7468 - val_loss: 0.5840 - val_auc: 0.7474
# Epoch 13/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5842 - auc: 0.7473 - val_loss: 0.5839 - val_auc: 0.7479
# Epoch 14/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5843 - auc: 0.7472 - val_loss: 0.5825 - val_auc: 0.7482
# Epoch 15/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5827 - auc: 0.7485 - val_loss: 0.5882 - val_auc: 0.7485
# Epoch 16/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5828 - auc: 0.7481 - val_loss: 0.5812 - val_auc: 0.7488
# Epoch 17/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5813 - auc: 0.7490 - val_loss: 0.5806 - val_auc: 0.7494
# Epoch 18/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5811 - auc: 0.7491 - val_loss: 0.5815 - val_auc: 0.7490
# Epoch 19/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5812 - auc: 0.7492 - val_loss: 0.5796 - val_auc: 0.7499
# Epoch 20/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5804 - auc: 0.7497 - val_loss: 0.5791 - val_auc: 0.7497
# Epoch 21/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5795 - auc: 0.7500 - val_loss: 0.5791 - val_auc: 0.7500
# Epoch 22/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5789 - auc: 0.7503 - val_loss: 0.5785 - val_auc: 0.7503
# Epoch 23/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5790 - auc: 0.7500 - val_loss: 0.5803 - val_auc: 0.7506
# Epoch 24/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5783 - auc: 0.7505 - val_loss: 0.5781 - val_auc: 0.7502
# Epoch 25/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5783 - auc: 0.7504 - val_loss: 0.5842 - val_auc: 0.7503
# Epoch 26/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5782 - auc: 0.7502 - val_loss: 0.5769 - val_auc: 0.7510
# Epoch 27/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5776 - auc: 0.7509 - val_loss: 0.5766 - val_auc: 0.7499
# Epoch 28/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5773 - auc: 0.7508 - val_loss: 0.5904 - val_auc: 0.7502
# Epoch 29/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5768 - auc: 0.7510 - val_loss: 0.5814 - val_auc: 0.7514
# Epoch 30/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5775 - auc: 0.7506 - val_loss: 0.5760 - val_auc: 0.7505
# Epoch 31/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5770 - auc: 0.7508 - val_loss: 0.5766 - val_auc: 0.7511
# Epoch 32/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5772 - auc: 0.7510 - val_loss: 0.5756 - val_auc: 0.7509
# Epoch 33/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5756 - auc: 0.7516 - val_loss: 0.5828 - val_auc: 0.7508
# Epoch 34/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5767 - auc: 0.7513 - val_loss: 0.5764 - val_auc: 0.7514
# Epoch 35/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5763 - auc: 0.7514 - val_loss: 0.5766 - val_auc: 0.7505
# Epoch 36/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5750 - auc: 0.7521 - val_loss: 0.5823 - val_auc: 0.7512
# Epoch 37/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5756 - auc: 0.7517 - val_loss: 0.5826 - val_auc: 0.7520
# Epoch 38/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5733 - auc: 0.7531 - val_loss: 0.5738 - val_auc: 0.7515
# Epoch 39/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5732 - auc: 0.7533 - val_loss: 0.5739 - val_auc: 0.7515
# Epoch 40/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5732 - auc: 0.7533 - val_loss: 0.5740 - val_auc: 0.7517
# Epoch 41/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5730 - auc: 0.7534 - val_loss: 0.5738 - val_auc: 0.7515
# Epoch 42/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5731 - auc: 0.7535 - val_loss: 0.5742 - val_auc: 0.7516
# Epoch 43/1000
# 235/235 [==============================] - 2s 6ms/step - loss: 0.5728 - auc: 0.7535 - val_loss: 0.5738 - val_auc: 0.7517
# Epoch 44/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5723 - auc: 0.7540 - val_loss: 0.5734 - val_auc: 0.7517
# Epoch 45/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5723 - auc: 0.7539 - val_loss: 0.5736 - val_auc: 0.7517
# Epoch 46/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5723 - auc: 0.7538 - val_loss: 0.5734 - val_auc: 0.7519
# Epoch 47/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5723 - auc: 0.7539 - val_loss: 0.5736 - val_auc: 0.7520
# Epoch 48/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5723 - auc: 0.7539 - val_loss: 0.5733 - val_auc: 0.7518
# Epoch 49/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5723 - auc: 0.7539 - val_loss: 0.5732 - val_auc: 0.7519
# Epoch 50/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5722 - auc: 0.7539 - val_loss: 0.5733 - val_auc: 0.7520
# Epoch 51/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5723 - auc: 0.7540 - val_loss: 0.5734 - val_auc: 0.7518
# Epoch 52/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5722 - auc: 0.7540 - val_loss: 0.5732 - val_auc: 0.7521
# Epoch 53/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5722 - auc: 0.7540 - val_loss: 0.5732 - val_auc: 0.7520
# Epoch 54/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5720 - auc: 0.7542 - val_loss: 0.5731 - val_auc: 0.7520
# Epoch 55/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5720 - auc: 0.7541 - val_loss: 0.5731 - val_auc: 0.7521
# Epoch 56/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5720 - auc: 0.7541 - val_loss: 0.5732 - val_auc: 0.7520
# Epoch 57/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5720 - auc: 0.7541 - val_loss: 0.5732 - val_auc: 0.7519
# Epoch 58/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5720 - auc: 0.7541 - val_loss: 0.5732 - val_auc: 0.7518
# Epoch 59/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5720 - auc: 0.7541 - val_loss: 0.5731 - val_auc: 0.7519
# Epoch 60/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5719 - auc: 0.7542 - val_loss: 0.5731 - val_auc: 0.7519
# Epoch 61/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5720 - auc: 0.7541 - val_loss: 0.5731 - val_auc: 0.7520
# Epoch 62/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5719 - auc: 0.7542 - val_loss: 0.5731 - val_auc: 0.7519
# Epoch 63/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5719 - auc: 0.7541 - val_loss: 0.5731 - val_auc: 0.7519
# Epoch 64/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5719 - auc: 0.7542 - val_loss: 0.5731 - val_auc: 0.7519
# Epoch 65/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5719 - auc: 0.7541 - val_loss: 0.5731 - val_auc: 0.7519
# Epoch 66/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5719 - auc: 0.7542 - val_loss: 0.5731 - val_auc: 0.7519
# Epoch 67/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5719 - auc: 0.7542 - val_loss: 0.5731 - val_auc: 0.7519
# Epoch 68/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5719 - auc: 0.7542 - val_loss: 0.5731 - val_auc: 0.7519
# Epoch 69/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5719 - auc: 0.7542 - val_loss: 0.5731 - val_auc: 0.7519
# Epoch 70/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5719 - auc: 0.7542 - val_loss: 0.5731 - val_auc: 0.7519
# Epoch 71/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5719 - auc: 0.7542 - val_loss: 0.5731 - val_auc: 0.7519
# Epoch 72/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5719 - auc: 0.7542 - val_loss: 0.5731 - val_auc: 0.7519
# Epoch 73/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5719 - auc: 0.7542 - val_loss: 0.5731 - val_auc: 0.7519
# Epoch 74/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5719 - auc: 0.7542 - val_loss: 0.5731 - val_auc: 0.7519
# Epoch 75/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5719 - auc: 0.7542 - val_loss: 0.5731 - val_auc: 0.7519
# Epoch 76/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5719 - auc: 0.7542 - val_loss: 0.5731 - val_auc: 0.7519
# Epoch 77/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5719 - auc: 0.7542 - val_loss: 0.5731 - val_auc: 0.7519
# Epoch 78/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5719 - auc: 0.7542 - val_loss: 0.5731 - val_auc: 0.7519
# Epoch 79/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5719 - auc: 0.7542 - val_loss: 0.5731 - val_auc: 0.7519
# Epoch 80/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5719 - auc: 0.7542 - val_loss: 0.5731 - val_auc: 0.7519
# Epoch 81/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5719 - auc: 0.7542 - val_loss: 0.5731 - val_auc: 0.7519
# Epoch 82/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5719 - auc: 0.7542 - val_loss: 0.5731 - val_auc: 0.7519
# Epoch 83/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5719 - auc: 0.7542 - val_loss: 0.5731 - val_auc: 0.7519
# Epoch 84/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5719 - auc: 0.7542 - val_loss: 0.5731 - val_auc: 0.7519
# Epoch 85/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5719 - auc: 0.7542 - val_loss: 0.5731 - val_auc: 0.7519
# Epoch 86/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5719 - auc: 0.7542 - val_loss: 0.5731 - val_auc: 0.7519
# Epoch 87/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5719 - auc: 0.7542 - val_loss: 0.5731 - val_auc: 0.7519
# Epoch 88/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5719 - auc: 0.7542 - val_loss: 0.5731 - val_auc: 0.7519
# Epoch 89/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5719 - auc: 0.7542 - val_loss: 0.5731 - val_auc: 0.7519
# Epoch 90/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5719 - auc: 0.7542 - val_loss: 0.5731 - val_auc: 0.7519
# Epoch 91/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5719 - auc: 0.7542 - val_loss: 0.5731 - val_auc: 0.7519
# Epoch 92/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5719 - auc: 0.7542 - val_loss: 0.5731 - val_auc: 0.7519
# Epoch 93/1000
# 235/235 [==============================] - 2s 6ms/step - loss: 0.5719 - auc: 0.7542 - val_loss: 0.5731 - val_auc: 0.7519
# Epoch 94/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5719 - auc: 0.7542 - val_loss: 0.5731 - val_auc: 0.7519
# Fold 4 NN: 0.75197
# Training fold 5
# CV 5/5
# Epoch 1/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.6252 - auc: 0.7219 - val_loss: 0.6192 - val_auc: 0.7328
# Epoch 2/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.6154 - auc: 0.7335 - val_loss: 0.6149 - val_auc: 0.7367
# Epoch 3/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.6132 - auc: 0.7370 - val_loss: 0.6136 - val_auc: 0.7393
# Epoch 4/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.6118 - auc: 0.7391 - val_loss: 0.6113 - val_auc: 0.7410
# Epoch 5/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.6091 - auc: 0.7408 - val_loss: 0.6049 - val_auc: 0.7416
# Epoch 6/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5982 - auc: 0.7405 - val_loss: 0.5945 - val_auc: 0.7424
# Epoch 7/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5932 - auc: 0.7423 - val_loss: 0.5906 - val_auc: 0.7441
# Epoch 8/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5900 - auc: 0.7442 - val_loss: 0.5969 - val_auc: 0.7461
# Epoch 9/1000
# 235/235 [==============================] - 2s 8ms/step - loss: 0.5891 - auc: 0.7444 - val_loss: 0.5887 - val_auc: 0.7471
# Epoch 10/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5877 - auc: 0.7451 - val_loss: 0.5868 - val_auc: 0.7474
# Epoch 11/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5855 - auc: 0.7468 - val_loss: 0.5842 - val_auc: 0.7484
# Epoch 12/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5849 - auc: 0.7469 - val_loss: 0.5822 - val_auc: 0.7488
# Epoch 13/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5836 - auc: 0.7478 - val_loss: 0.5836 - val_auc: 0.7495
# Epoch 14/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5826 - auc: 0.7483 - val_loss: 0.5800 - val_auc: 0.7500
# Epoch 15/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5819 - auc: 0.7486 - val_loss: 0.5839 - val_auc: 0.7501
# Epoch 16/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5831 - auc: 0.7480 - val_loss: 0.5794 - val_auc: 0.7504
# Epoch 17/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5801 - auc: 0.7496 - val_loss: 0.5850 - val_auc: 0.7510
# Epoch 18/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5805 - auc: 0.7493 - val_loss: 0.5779 - val_auc: 0.7510
# Epoch 19/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5795 - auc: 0.7498 - val_loss: 0.5811 - val_auc: 0.7506
# Epoch 20/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5789 - auc: 0.7501 - val_loss: 0.5776 - val_auc: 0.7514
# Epoch 21/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5784 - auc: 0.7504 - val_loss: 0.5771 - val_auc: 0.7513
# Epoch 22/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5788 - auc: 0.7503 - val_loss: 0.5774 - val_auc: 0.7516
# Epoch 23/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5779 - auc: 0.7508 - val_loss: 0.5775 - val_auc: 0.7517
# Epoch 24/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5771 - auc: 0.7511 - val_loss: 0.5779 - val_auc: 0.7516
# Epoch 25/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5766 - auc: 0.7512 - val_loss: 0.5751 - val_auc: 0.7514
# Epoch 26/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5765 - auc: 0.7514 - val_loss: 0.5755 - val_auc: 0.7513
# Epoch 27/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5758 - auc: 0.7515 - val_loss: 0.5753 - val_auc: 0.7519
# Epoch 28/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5766 - auc: 0.7512 - val_loss: 0.5744 - val_auc: 0.7519
# Epoch 29/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5756 - auc: 0.7517 - val_loss: 0.5751 - val_auc: 0.7521
# Epoch 30/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5752 - auc: 0.7518 - val_loss: 0.5738 - val_auc: 0.7522
# Epoch 31/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5766 - auc: 0.7515 - val_loss: 0.5750 - val_auc: 0.7512
# Epoch 32/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5763 - auc: 0.7517 - val_loss: 0.5752 - val_auc: 0.7522
# Epoch 33/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5748 - auc: 0.7524 - val_loss: 0.5744 - val_auc: 0.7512
# Epoch 34/1000
# 235/235 [==============================] - 2s 8ms/step - loss: 0.5748 - auc: 0.7523 - val_loss: 0.5805 - val_auc: 0.7518
# Epoch 35/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5753 - auc: 0.7521 - val_loss: 0.5785 - val_auc: 0.7517
# Epoch 36/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5727 - auc: 0.7534 - val_loss: 0.5729 - val_auc: 0.7521
# Epoch 37/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5722 - auc: 0.7536 - val_loss: 0.5726 - val_auc: 0.7521
# Epoch 38/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5725 - auc: 0.7536 - val_loss: 0.5739 - val_auc: 0.7521
# Epoch 39/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5723 - auc: 0.7537 - val_loss: 0.5726 - val_auc: 0.7521
# Epoch 40/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5721 - auc: 0.7536 - val_loss: 0.5729 - val_auc: 0.7521
# Epoch 41/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5722 - auc: 0.7537 - val_loss: 0.5725 - val_auc: 0.7522
# Epoch 42/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5723 - auc: 0.7537 - val_loss: 0.5726 - val_auc: 0.7523
# Epoch 43/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5722 - auc: 0.7538 - val_loss: 0.5741 - val_auc: 0.7523
# Epoch 44/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5720 - auc: 0.7537 - val_loss: 0.5725 - val_auc: 0.7523
# Epoch 45/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5721 - auc: 0.7538 - val_loss: 0.5725 - val_auc: 0.7520
# Epoch 46/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5720 - auc: 0.7538 - val_loss: 0.5724 - val_auc: 0.7521
# Epoch 47/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5713 - auc: 0.7544 - val_loss: 0.5721 - val_auc: 0.7525
# Epoch 48/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5713 - auc: 0.7544 - val_loss: 0.5720 - val_auc: 0.7523
# Epoch 49/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5712 - auc: 0.7544 - val_loss: 0.5721 - val_auc: 0.7523
# Epoch 50/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5712 - auc: 0.7544 - val_loss: 0.5721 - val_auc: 0.7524
# Epoch 51/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5712 - auc: 0.7544 - val_loss: 0.5721 - val_auc: 0.7523
# Epoch 52/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5712 - auc: 0.7544 - val_loss: 0.5720 - val_auc: 0.7523
# Epoch 53/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5711 - auc: 0.7545 - val_loss: 0.5720 - val_auc: 0.7524
# Epoch 54/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5710 - auc: 0.7546 - val_loss: 0.5720 - val_auc: 0.7524
# Epoch 55/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5711 - auc: 0.7545 - val_loss: 0.5720 - val_auc: 0.7524
# Epoch 56/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5710 - auc: 0.7545 - val_loss: 0.5719 - val_auc: 0.7523
# Epoch 57/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5710 - auc: 0.7545 - val_loss: 0.5720 - val_auc: 0.7523
# Epoch 58/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5710 - auc: 0.7545 - val_loss: 0.5720 - val_auc: 0.7524
# Epoch 59/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5710 - auc: 0.7546 - val_loss: 0.5719 - val_auc: 0.7523
# Epoch 60/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5710 - auc: 0.7546 - val_loss: 0.5720 - val_auc: 0.7523
# Epoch 61/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5710 - auc: 0.7546 - val_loss: 0.5719 - val_auc: 0.7524
# Epoch 62/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5710 - auc: 0.7546 - val_loss: 0.5719 - val_auc: 0.7523
# Epoch 63/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5710 - auc: 0.7546 - val_loss: 0.5720 - val_auc: 0.7523
# Epoch 64/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5710 - auc: 0.7546 - val_loss: 0.5719 - val_auc: 0.7524
# Epoch 65/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5710 - auc: 0.7546 - val_loss: 0.5719 - val_auc: 0.7524
# Epoch 66/1000
# 235/235 [==============================] - 2s 6ms/step - loss: 0.5710 - auc: 0.7546 - val_loss: 0.5719 - val_auc: 0.7524
# Epoch 67/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5710 - auc: 0.7546 - val_loss: 0.5719 - val_auc: 0.7523
# Epoch 68/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5710 - auc: 0.7546 - val_loss: 0.5719 - val_auc: 0.7524
# Epoch 69/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5710 - auc: 0.7546 - val_loss: 0.5719 - val_auc: 0.7524
# Epoch 70/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5710 - auc: 0.7546 - val_loss: 0.5719 - val_auc: 0.7524
# Epoch 71/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5710 - auc: 0.7546 - val_loss: 0.5719 - val_auc: 0.7524
# Epoch 72/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5710 - auc: 0.7546 - val_loss: 0.5719 - val_auc: 0.7524
# Epoch 73/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5710 - auc: 0.7546 - val_loss: 0.5719 - val_auc: 0.7524
# Epoch 74/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5710 - auc: 0.7546 - val_loss: 0.5719 - val_auc: 0.7524
# Epoch 75/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5710 - auc: 0.7546 - val_loss: 0.5719 - val_auc: 0.7524
# Epoch 76/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5710 - auc: 0.7546 - val_loss: 0.5719 - val_auc: 0.7524
# Epoch 77/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5710 - auc: 0.7546 - val_loss: 0.5719 - val_auc: 0.7524
# Epoch 78/1000
# 235/235 [==============================] - 1s 6ms/step - loss: 0.5710 - auc: 0.7546 - val_loss: 0.5719 - val_auc: 0.7524
# Epoch 79/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5710 - auc: 0.7546 - val_loss: 0.5719 - val_auc: 0.7524
# Epoch 80/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5710 - auc: 0.7546 - val_loss: 0.5719 - val_auc: 0.7524
# Epoch 81/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5710 - auc: 0.7546 - val_loss: 0.5719 - val_auc: 0.7524
# Epoch 82/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5710 - auc: 0.7546 - val_loss: 0.5719 - val_auc: 0.7524
# Epoch 83/1000
# 235/235 [==============================] - 2s 7ms/step - loss: 0.5710 - auc: 0.7546 - val_loss: 0.5719 - val_auc: 0.7524
# Epoch 84/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5710 - auc: 0.7546 - val_loss: 0.5719 - val_auc: 0.7524
# Epoch 85/1000
# 235/235 [==============================] - 2s 8ms/step - loss: 0.5710 - auc: 0.7546 - val_loss: 0.5719 - val_auc: 0.7524
# Epoch 86/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5710 - auc: 0.7546 - val_loss: 0.5719 - val_auc: 0.7524
# Epoch 87/1000
# 235/235 [==============================] - 1s 5ms/step - loss: 0.5710 - auc: 0.7546 - val_loss: 0.5719 - val_auc: 0.7524
# Fold 5 NN: 0.75232

# %%
print(scores_folds)
# Out:
# {'NN': [0.75202, 0.75256, 0.75248, 0.75197, 0.75232]}

# %%
sub=pd.read_csv("../input/tabular-playground-series-nov-2021/sample_submission.csv")
sub['target']=test_predictions_nn

# %%
sub
# Out:
#              id    target
# 0        600000  0.732998
# 1        600001  0.756250
# 2        600002  0.757803
# 3        600003  0.514915
# 4        600004  0.727488
# ...         ...       ...
# 539995  1139995  0.763161
# 539996  1139996  0.743610
# 539997  1139997  0.625510
# 539998  1139998  0.736090
# 539999  1139999  0.757531
#
# [540000 rows x 2 columns]

# %%
sub.to_csv("submission.csv",index=False)
